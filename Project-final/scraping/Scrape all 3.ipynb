# %% [markdown]
# # This Notebook scrapes BC, ON, AB data and creates a csv called "ONABBC_Data.csv"

# %%
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time
import csv

# %%
CSV_URL = 'https://data.ontario.ca/dataset/f4112442-bdc8-45d2-be3c-12efae72fb27/resource/455fd63b-603d-4608-8216-7d8647f43350/download/conposcovidloc.csv'
with requests.Session() as s:
   download = s.get(CSV_URL)
   decoded_content = download.content.decode('utf-8')
   cr = csv.DictReader(decoded_content.splitlines(), delimiter=',')
   my_list = list(cr)
   for row in my_list:
    print(row)
# Out:
# OrderedDict([('Row_ID', '1'), ('Accurate_Episode_Date', '2020-01-22'), ('Case_Reported_Date', '2020-01-23'), ('Test_Reported_Date', '2020-01-27'), ('Specimen_Date', '2020-01-25'), ('Age_Group', '50s'), ('Client_Gender', 'FEMALE'), ('Case_AcquisitionInfo', 'Travel-Related'), ('Outcome1', 'Resolved'), ('Outbreak_Related', ''), ('Reporting_PHU', 'Toronto Public Health'), ('Reporting_PHU_Address', '277 Victoria Street, 5th Floor'), ('Reporting_PHU_City', 'Toronto'), ('Reporting_PHU_Postal_Code', 'M5B 1W2'), ('Reporting_PHU_Website', 'www.toronto.ca/community-people/health-wellness-care/'), ('Reporting_PHU_Latitude', '43.65659125'), ('Reporting_PHU_Longitude', '-79.37935801')])
# ...

# %%
my_list
# Out:
# [OrderedDict([('Row_ID', '1'),
#               ('Accurate_Episode_Date', '2020-01-22'),
#               ('Case_Reported_Date', '2020-01-23'),
#               ('Test_Reported_Date', '2020-01-27'),
#               ('Specimen_Date', '2020-01-25'),
#               ('Age_Group', '50s'),
#               ('Client_Gender', 'FEMALE'),
#               ('Case_AcquisitionInfo', 'Travel-Related'),
#               ('Outcome1', 'Resolved'),
#               ('Outbreak_Related', ''),
#               ('Reporting_PHU', 'Toronto Public Health'),
#               ('Reporting_PHU_Address', '277 Victoria Street, 5th Floor'),
#               ('Reporting_PHU_City', 'Toronto'),
#               ('Reporting_PHU_Postal_Code', 'M5B 1W2'),
#               ('Reporting_PHU_Website',
#                'www.toronto.ca/community-people/health-wellness-care/'),
#               ('Reporting_PHU_Latitude', '43.65659125'),
#               ('Reporting_PHU_Longitude', '-79.37935801')]),
#  OrderedDict([('Row_ID', '2'),
# ...

# %%
meow=pd.DataFrame(my_list)

# %%
meow2 = meow.drop(columns= ["Row_ID", "Case_AcquisitionInfo", "Outbreak_Related","Reporting_PHU","Reporting_PHU_Address","Reporting_PHU_Website"])
meow2
# Out:
#       Accurate_Episode_Date Case_Reported_Date Test_Reported_Date  \
# 0                2020-01-22         2020-01-23         2020-01-27
# 1                2020-01-21         2020-01-23         2020-01-27
# 2                2020-01-24         2020-01-24         2020-02-03
# 3                2020-02-05         2020-02-21         2020-02-24
# 4                2020-02-16         2020-02-25         2020-02-25
# ...                     ...                ...                ...
# 31336            2020-06-08         2020-06-09         2020-06-09
# 31337            2020-06-05         2020-06-09         2020-06-09
# 31338            2020-06-08         2020-06-09         2020-06-09
# 31339            2020-06-08         2020-06-09         2020-06-09
# 31340            2020-06-08         2020-06-09         2020-06-08
#
#       Specimen_Date Age_Group Client_Gender      Outcome1 Reporting_PHU_City  \
# 0        2020-01-25       50s        FEMALE      Resolved            Toronto
# ...

# %%
meow3 = meow2.rename(columns={'Accurate_Episode_Date':'Case_Date',
                      'Age_Group':'Age_Group',
                      'Client_Gender':'Gender',
                      'Outcome1':'Outcome',
                      'Reporting_PHU_City':'City/Health_Region',
                      'Reporting_PHU_Postal_Code':'Postal_Code',
                      'Reporting_PHU_Latitude':'Latitude', 
                      'Reporting_PHU_Longitude':'Longitude'})

# %% [markdown]
# # Use Meow3 or Meow4 for ontario heatmap

# %%
meow3.loc[meow3['Age_Group'] == "50s", 'Age_Group'] = "50-59 years"
meow3.loc[meow3['Age_Group'] == "40s", 'Age_Group'] = "40-49 years"
meow3.loc[meow3['Age_Group'] == "20s", 'Age_Group'] = "20-29 years"
meow3.loc[meow3['Age_Group'] == "30s", 'Age_Group'] = "30-39 years"
meow3.loc[meow3['Age_Group'] == "60s", 'Age_Group'] = "60-69 years"
meow3.loc[meow3['Age_Group'] == "70s", 'Age_Group'] = "70-79 years"
meow3.loc[meow3['Age_Group'] == "80s", 'Age_Group'] = "80+ years"
meow3.loc[meow3['Age_Group'] == "90s", 'Age_Group'] = "80+ years"
meow3.loc[meow3['Age_Group'] == "<20", 'Age_Group'] = "<20 years"

meow3
# Out:
#         Case_Date Case_Reported_Date Test_Reported_Date Specimen_Date  \
# 0      2020-01-22         2020-01-23         2020-01-27    2020-01-25
# 1      2020-01-21         2020-01-23         2020-01-27    2020-01-23
# 2      2020-01-24         2020-01-24         2020-02-03    2020-01-24
# 3      2020-02-05         2020-02-21         2020-02-24    2020-02-22
# 4      2020-02-16         2020-02-25         2020-02-25    2020-02-25
# ...           ...                ...                ...           ...
# 31336  2020-06-08         2020-06-09         2020-06-09    2020-06-08
# 31337  2020-06-05         2020-06-09         2020-06-09    2020-06-08
# 31338  2020-06-08         2020-06-09         2020-06-09    2020-06-08
# 31339  2020-06-08         2020-06-09         2020-06-09    2020-06-08
# 31340  2020-06-08         2020-06-09         2020-06-08    2020-06-08
#
#          Age_Group  Gender       Outcome City/Health_Region Postal_Code  \
# ...

# %%
meow4=meow3.drop(columns=["Postal_Code"])
meow4
# Out:
#         Case_Date Case_Reported_Date Test_Reported_Date Specimen_Date  \
# 0      2020-01-22         2020-01-23         2020-01-27    2020-01-25
# 1      2020-01-21         2020-01-23         2020-01-27    2020-01-23
# 2      2020-01-24         2020-01-24         2020-02-03    2020-01-24
# 3      2020-02-05         2020-02-21         2020-02-24    2020-02-22
# 4      2020-02-16         2020-02-25         2020-02-25    2020-02-25
# ...           ...                ...                ...           ...
# 31336  2020-06-08         2020-06-09         2020-06-09    2020-06-08
# 31337  2020-06-05         2020-06-09         2020-06-09    2020-06-08
# 31338  2020-06-08         2020-06-09         2020-06-09    2020-06-08
# 31339  2020-06-08         2020-06-09         2020-06-09    2020-06-08
# 31340  2020-06-08         2020-06-09         2020-06-08    2020-06-08
#
#          Age_Group  Gender       Outcome City/Health_Region     Latitude  \
# ...

# %%
meow4.loc[meow3['Gender'] == "FEMALE", 'Gender'] = "Female"
meow4.loc[meow3['Gender'] == "MALE", 'Gender'] = "Male"


meow4
# Out:
#         Case_Date Case_Reported_Date Test_Reported_Date Specimen_Date  \
# 0      2020-01-22         2020-01-23         2020-01-27    2020-01-25
# 1      2020-01-21         2020-01-23         2020-01-27    2020-01-23
# 2      2020-01-24         2020-01-24         2020-02-03    2020-01-24
# 3      2020-02-05         2020-02-21         2020-02-24    2020-02-22
# 4      2020-02-16         2020-02-25         2020-02-25    2020-02-25
# ...           ...                ...                ...           ...
# 31336  2020-06-08         2020-06-09         2020-06-09    2020-06-08
# 31337  2020-06-05         2020-06-09         2020-06-09    2020-06-08
# 31338  2020-06-08         2020-06-09         2020-06-09    2020-06-08
# 31339  2020-06-08         2020-06-09         2020-06-09    2020-06-08
# 31340  2020-06-08         2020-06-09         2020-06-08    2020-06-08
#
#          Age_Group  Gender       Outcome City/Health_Region     Latitude  \
# ...

# %%
meow4["Province"] = "Ontario"

# %%
meow4.Outcome.unique()
# Out:
# array(['Resolved', 'Fatal', 'Not Resolved'], dtype=object)

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path)
##browser = Browser('firefox')

# %%
url = 'https://www.alberta.ca/stats/covid-19-alberta-statistics.htm'
browser.visit(url)
browser.click_link_by_partial_text('Data export')

##browser.execute_script("$('#DataTables_Table_0_length option:nth-child(4)').attr('value', '10000');")

##element = browser.find_by_name('DataTables_Table_0_length')

##element.select("10000")
##time.sleep(2)

# %%
html = browser.html
##html = requests.get(url)
##with open("test.html","w") as f:
    ##f.write(str(html.text.encode('utf-8')))
soup = BeautifulSoup(html, 'html.parser')

# %%
table = soup.find('div', class_='dataTables_scrollBody')
table_rows = table.find_all('tr')

# %%
# Function to Click Next Page        
def click_next_page():
    browser.click_link_by_partial_text('Next')


res = []
page = 1
while page <145:
    print ('Page: %s' %page)
    table = soup.find('div', class_='dataTables_scrollBody')
    table_rows = table.find_all('tr')

    for x in table_rows:
        td = x.find_all('td')
        row = [x.text.strip() for x in td if x.text.strip()]
        if row:
            res.append(row)

    ## Your code to Parse the Tables ## 

    try:
        click_next_page()
        page += 1
    except:
        print ('You are at the end')
        ##num_of_pages == False


    ##time.sleep(0)






# When finished
# Out:
# Page: 1
# Page: 2
# Page: 3
# Page: 4
# Page: 5
# Page: 6
# Page: 7
# Page: 8
# Page: 9
# Page: 10
# Page: 11
# Page: 12
# Page: 13
# Page: 14
# Page: 15
# Page: 16
# Page: 17
# Page: 18
# Page: 19
# Page: 20
# Page: 21
# Page: 22
# Page: 23
# Page: 24
# Page: 25
# Page: 26
# Page: 27
# Page: 28
# Page: 29
# Page: 30
# Page: 31
# Page: 32
# Page: 33
# Page: 34
# Page: 35
# Page: 36
# Page: 37
# Page: 38
# Page: 39
# Page: 40
# Page: 41
# Page: 42
# Page: 43
# Page: 44
# Page: 45
# Page: 46
# Page: 47
# Page: 48
# Page: 49
# Page: 50
# Page: 51
# Page: 52
# Page: 53
# Page: 54
# Page: 55
# Page: 56
# Page: 57
# Page: 58
# Page: 59
# Page: 60
# Page: 61
# Page: 62
# Page: 63
# Page: 64
# Page: 65
# Page: 66
# Page: 67
# Page: 68
# Page: 69
# Page: 70
# Page: 71
# Page: 72
# Page: 73
# Page: 74
# Page: 75
# Page: 76
# Page: 77
# Page: 78
# Page: 79
# Page: 80
# Page: 81
# Page: 82
# Page: 83
# Page: 84
# Page: 85
# Page: 86
# Page: 87
# Page: 88
# Page: 89
# Page: 90
# Page: 91
# ...

# %%
df = pd.DataFrame(res, columns=["index1","Date Reported","Alberta Health Zone","Gender","Age Group","Case Status", "Case Type"])
df
# Out:
#                       index1 Date Reported Alberta Health Zone  Gender  \
# 0     2020-03-06\n2020-06-09          None                None    None
# 1                          1    2020-03-06        Calgary Zone  Female
# 2                          2    2020-03-09        Calgary Zone  Female
# 3                          3    2020-03-09        Calgary Zone    Male
# 4                          4    2020-03-09       Edmonton Zone    Male
# ...                      ...           ...                 ...     ...
# 7339                      46    2020-03-16        Calgary Zone  Female
# 7340                      47    2020-03-14       Edmonton Zone  Female
# 7341                      48    2020-03-14       Edmonton Zone  Female
# 7342                      49    2020-03-14        Calgary Zone    Male
# 7343                      50    2020-03-15        Calgary Zone    Male
#
#         Age Group Case Status  Case Type
# 0            None        None       None
# ...

# %% [raw]
# If the splinter application fails which it can sometimes, i've included a CSV with the alberta data so that the rest of the project will still work.

# %%
df = pd.read_csv("alberta_data.csv") 
df
# Out:
#       Unnamed: 0 Date reported Alberta Health Services Zone   Gender  \
# 0              1    2020-03-06                 Calgary Zone   Female
# 1              2    2020-03-09                 Calgary Zone   Female
# 2              3    2020-03-09                 Calgary Zone     Male
# 3              4    2020-03-09                Edmonton Zone     Male
# 4              5    2020-03-09                Edmonton Zone     Male
# ...          ...           ...                          ...      ...
# 7224        7225    2020-05-31                   South Zone     Male
# 7225        7226    2020-05-31                   South Zone     Male
# 7226        7227    2020-06-07                Edmonton Zone     Male
# 7227        7228    2020-06-09                Edmonton Zone   Female
# 7228        7229    2020-05-19                   South Zone  Unknown
#
#         Age group Case status  Case type
# 0     50-59 years   Recovered  Confirmed
# 1     30-39 years   Recovered  Confirmed
# ...

# %%
df2=df.drop(columns=["Unnamed: 0","Case type"])
df2
# Out:
#      Date reported Alberta Health Services Zone   Gender    Age group  \
# 0       2020-03-06                 Calgary Zone   Female  50-59 years
# 1       2020-03-09                 Calgary Zone   Female  30-39 years
# 2       2020-03-09                 Calgary Zone     Male  30-39 years
# 3       2020-03-09                Edmonton Zone     Male  60-69 years
# 4       2020-03-09                Edmonton Zone     Male  40-49 years
# ...            ...                          ...      ...          ...
# 7224    2020-05-31                   South Zone     Male  20-29 years
# 7225    2020-05-31                   South Zone     Male  20-29 years
# 7226    2020-06-07                Edmonton Zone     Male  60-69 years
# 7227    2020-06-09                Edmonton Zone   Female  60-69 years
# 7228    2020-05-19                   South Zone  Unknown    5-9 years
#
#      Case status
# 0      Recovered
# 1      Recovered
# 2      Recovered
# 3      Recovered
# 4      Recovered
# ...

# %%
df3 = df2.rename(columns={'Date Reported':'Case_Date',
                      'Age Group':'Age_Group',
                      'Gender':'Gender',
                      'Case Status':'Outcome',
                      'Alberta Health Zone':'City/Health_Region'
                })
df3
# Out:
#      Date reported Alberta Health Services Zone   Gender    Age group  \
# 0       2020-03-06                 Calgary Zone   Female  50-59 years
# 1       2020-03-09                 Calgary Zone   Female  30-39 years
# 2       2020-03-09                 Calgary Zone     Male  30-39 years
# 3       2020-03-09                Edmonton Zone     Male  60-69 years
# 4       2020-03-09                Edmonton Zone     Male  40-49 years
# ...            ...                          ...      ...          ...
# 7224    2020-05-31                   South Zone     Male  20-29 years
# 7225    2020-05-31                   South Zone     Male  20-29 years
# 7226    2020-06-07                Edmonton Zone     Male  60-69 years
# 7227    2020-06-09                Edmonton Zone   Female  60-69 years
# 7228    2020-05-19                   South Zone  Unknown    5-9 years
#
#      Case status
# 0      Recovered
# 1      Recovered
# 2      Recovered
# 3      Recovered
# 4      Recovered
# ...

# %%
mapping = {df2.columns[0]:'Case_Date', df2.columns[1]: 'City/Health_Region', df2.columns[2]:'Gender', df2.columns[3]: 'Age_Group',df2.columns[4]:'Outcome'}
df3 = df2.rename(columns=mapping)

# %%
df3
# Out:
#        Case_Date City/Health_Region   Gender    Age_Group    Outcome
# 0     2020-03-06       Calgary Zone   Female  50-59 years  Recovered
# 1     2020-03-09       Calgary Zone   Female  30-39 years  Recovered
# 2     2020-03-09       Calgary Zone     Male  30-39 years  Recovered
# 3     2020-03-09      Edmonton Zone     Male  60-69 years  Recovered
# 4     2020-03-09      Edmonton Zone     Male  40-49 years  Recovered
# ...          ...                ...      ...          ...        ...
# 7224  2020-05-31         South Zone     Male  20-29 years  Recovered
# 7225  2020-05-31         South Zone     Male  20-29 years  Recovered
# 7226  2020-06-07      Edmonton Zone     Male  60-69 years     Active
# 7227  2020-06-09      Edmonton Zone   Female  60-69 years     Active
# 7228  2020-05-19         South Zone  Unknown    5-9 years  Recovered
#
# [7229 rows x 5 columns]

# %%
df3[['Case_Date','Age_Group','Gender','Outcome','City/Health_Region']]
# Out:
#        Case_Date    Age_Group   Gender    Outcome City/Health_Region
# 0     2020-03-06  50-59 years   Female  Recovered       Calgary Zone
# 1     2020-03-09  30-39 years   Female  Recovered       Calgary Zone
# 2     2020-03-09  30-39 years     Male  Recovered       Calgary Zone
# 3     2020-03-09  60-69 years     Male  Recovered      Edmonton Zone
# 4     2020-03-09  40-49 years     Male  Recovered      Edmonton Zone
# ...          ...          ...      ...        ...                ...
# 7224  2020-05-31  20-29 years     Male  Recovered         South Zone
# 7225  2020-05-31  20-29 years     Male  Recovered         South Zone
# 7226  2020-06-07  60-69 years     Male     Active      Edmonton Zone
# 7227  2020-06-09  60-69 years   Female     Active      Edmonton Zone
# 7228  2020-05-19    5-9 years  Unknown  Recovered         South Zone
#
# [7229 rows x 5 columns]

# %%
df4=df3.drop(df.index[0])

# %%
df4.head(60)
# Out:
#      Case_Date City/Health_Region  Gender    Age_Group    Outcome
# 1   2020-03-09       Calgary Zone  Female  30-39 years  Recovered
# 2   2020-03-09       Calgary Zone    Male  30-39 years  Recovered
# 3   2020-03-09      Edmonton Zone    Male  60-69 years  Recovered
# 4   2020-03-09      Edmonton Zone    Male  40-49 years  Recovered
# 5   2020-03-09      Edmonton Zone  Female  70-79 years  Recovered
# 6   2020-03-10      Edmonton Zone    Male  70-79 years  Recovered
# 7   2020-03-10       Calgary Zone  Female  40-49 years  Recovered
# 8   2020-03-09       Calgary Zone  Female  50-59 years  Recovered
# 9   2020-03-10      Edmonton Zone  Female  60-69 years  Recovered
# 10  2020-03-10      Edmonton Zone  Female  20-29 years  Recovered
# 11  2020-03-10       Calgary Zone  Female  30-39 years  Recovered
# 12  2020-03-10       Calgary Zone  Female  30-39 years  Recovered
# 13  2020-03-10       Calgary Zone    Male  30-39 years  Recovered
# ...

# %%
df4.Age_Group.unique()
# Out:
# array(['30-39 years', '60-69 years', '40-49 years', '70-79 years',
#        '50-59 years', '20-29 years', '1-4 years', '10-19 years',
#        '5-9 years', '80+ years', 'Under 1 year', 'Unknown'], dtype=object)

# %%
df4.loc[df4['Age_Group'] == "1-4 years", 'Age_Group'] = "<20 years"
df4.loc[df4['Age_Group'] == "5-9 years", 'Age_Group'] = "<20 years"
df4.loc[df4['Age_Group'] == "10-19 years", 'Age_Group'] = "<20 years"

# %%
df4.loc[df4['Outcome'] == "10-19 years", 'Age_Group'] = "<20 years"

# %%
df4["Province"] = "Alberta"

# %%
df4.Outcome.unique()
# Out:
# array(['Recovered', 'Active', 'Died'], dtype=object)

# %%
df4
# Out:
#        Case_Date City/Health_Region   Gender    Age_Group    Outcome Province
# 1     2020-03-09       Calgary Zone   Female  30-39 years  Recovered  Alberta
# 2     2020-03-09       Calgary Zone     Male  30-39 years  Recovered  Alberta
# 3     2020-03-09      Edmonton Zone     Male  60-69 years  Recovered  Alberta
# 4     2020-03-09      Edmonton Zone     Male  40-49 years  Recovered  Alberta
# 5     2020-03-09      Edmonton Zone   Female  70-79 years  Recovered  Alberta
# ...          ...                ...      ...          ...        ...      ...
# 7224  2020-05-31         South Zone     Male  20-29 years  Recovered  Alberta
# 7225  2020-05-31         South Zone     Male  20-29 years  Recovered  Alberta
# 7226  2020-06-07      Edmonton Zone     Male  60-69 years     Active  Alberta
# 7227  2020-06-09      Edmonton Zone   Female  60-69 years     Active  Alberta
# 7228  2020-05-19         South Zone  Unknown    <20 years  Recovered  Alberta
#
# [7228 rows x 6 columns]

# %%
frames = [df4, meow4]

# %%
on_ab_df = pd.concat(frames)

# %%
on_ab_df2 = on_ab_df.drop(columns=["Case_Reported_Date","Test_Reported_Date","Specimen_Date"])
on_ab_df2
# Out:
#         Case_Date City/Health_Region  Gender    Age_Group       Outcome  \
# 1      2020-03-09       Calgary Zone  Female  30-39 years     Recovered
# 2      2020-03-09       Calgary Zone    Male  30-39 years     Recovered
# 3      2020-03-09      Edmonton Zone    Male  60-69 years     Recovered
# 4      2020-03-09      Edmonton Zone    Male  40-49 years     Recovered
# 5      2020-03-09      Edmonton Zone  Female  70-79 years     Recovered
# ...           ...                ...     ...          ...           ...
# 31336  2020-06-08             London    Male  60-69 years  Not Resolved
# 31337  2020-06-05             London    Male  20-29 years  Not Resolved
# 31338  2020-06-08             London    Male  20-29 years  Not Resolved
# 31339  2020-06-08             London  Female  60-69 years  Not Resolved
# 31340  2020-06-08             London  Female  20-29 years  Not Resolved
#
#       Province     Latitude     Longitude
# 1      Alberta          NaN           NaN
# ...

# %%
CSV_URL = 'http://www.bccdc.ca/Health-Info-Site/Documents/BCCDC_COVID19_Dashboard_Case_Details.csv'
with requests.Session() as s:
   download = s.get(CSV_URL)
   decoded_content = download.content.decode('utf-8')
   cr = csv.DictReader(decoded_content.splitlines(), delimiter=',')
   my_list = list(cr)
   for row in my_list:
    print(row)
# Out:
# OrderedDict([('Reported_Date', '2020-01-26'), ('HA', 'Vancouver Coastal'), ('Sex', 'M'), ('Age_Group', '40-49'), ('Classification_Reported', 'Lab-diagnosed')])
# OrderedDict([('Reported_Date', '2020-02-02'), ('HA', 'Vancouver Coastal'), ('Sex', 'F'), ('Age_Group', '50-59'), ('Classification_Reported', 'Lab-diagnosed')])
# OrderedDict([('Reported_Date', '2020-02-05'), ('HA', 'Vancouver Coastal'), ('Sex', 'F'), ('Age_Group', '20-29'), ('Classification_Reported', 'Lab-diagnosed')])
# OrderedDict([('Reported_Date', '2020-02-05'), ('HA', 'Vancouver Coastal'), ('Sex', 'M'), ('Age_Group', '30-39'), ('Classification_Reported', 'Lab-diagnosed')])
# OrderedDict([('Reported_Date', '2020-02-11'), ('HA', 'Interior'), ('Sex', 'F'), ('Age_Group', '30-39'), ('Classification_Reported', 'Lab-diagnosed')])
# OrderedDict([('Reported_Date', '2020-02-20'), ('HA', 'Fraser'), ('Sex', 'F'), ('Age_Group', '30-39'), ('Classification_Reported', 'Lab-diagnosed')])
# ...

# %%
data_BC = pd.DataFrame(my_list)
data_BC.head()
# Out:
#   Reported_Date                 HA Sex Age_Group Classification_Reported
# 0    2020-01-26  Vancouver Coastal   M     40-49           Lab-diagnosed
# 1    2020-02-02  Vancouver Coastal   F     50-59           Lab-diagnosed
# 2    2020-02-05  Vancouver Coastal   F     20-29           Lab-diagnosed
# 3    2020-02-05  Vancouver Coastal   M     30-39           Lab-diagnosed
# 4    2020-02-11           Interior   F     30-39           Lab-diagnosed

# %%
data_BC["Province"] = "British Colombia"

# %%
data_BC2 = data_BC.drop(columns=["Classification_Reported"])

# %%
mapping = {data_BC2.columns[0]:'Case_Date', data_BC2.columns[1]: 'City/Health_Region', data_BC2.columns[2]:'Gender', data_BC2.columns[3]: 'Age_Group',}
data_BC3 = data_BC2.rename(columns=mapping)

# %%
data_BC3
# Out:
#        Case_Date City/Health_Region Gender Age_Group          Province
# 0     2020-01-26  Vancouver Coastal      M     40-49  British Colombia
# 1     2020-02-02  Vancouver Coastal      F     50-59  British Colombia
# 2     2020-02-05  Vancouver Coastal      F     20-29  British Colombia
# 3     2020-02-05  Vancouver Coastal      M     30-39  British Colombia
# 4     2020-02-11           Interior      F     30-39  British Colombia
# ...          ...                ...    ...       ...               ...
# 2664  2020-06-08             Fraser      M       <10  British Colombia
# 2665  2020-06-08             Fraser      F       <10  British Colombia
# 2666  2020-06-08             Fraser      F     30-39  British Colombia
# 2667  2020-06-08           Northern      M     30-39  British Colombia
# 2668  2020-06-08  Vancouver Coastal      M     20-29  British Colombia
#
# [2669 rows x 5 columns]

# %%
frames2 = [data_BC3, on_ab_df2]

# %%
oab = pd.concat(frames2)
oab
# Out:
#         Case_Date City/Health_Region  Gender    Age_Group          Province  \
# 0      2020-01-26  Vancouver Coastal       M        40-49  British Colombia
# 1      2020-02-02  Vancouver Coastal       F        50-59  British Colombia
# 2      2020-02-05  Vancouver Coastal       F        20-29  British Colombia
# 3      2020-02-05  Vancouver Coastal       M        30-39  British Colombia
# 4      2020-02-11           Interior       F        30-39  British Colombia
# ...           ...                ...     ...          ...               ...
# 31336  2020-06-08             London    Male  60-69 years           Ontario
# 31337  2020-06-05             London    Male  20-29 years           Ontario
# 31338  2020-06-08             London    Male  20-29 years           Ontario
# 31339  2020-06-08             London  Female  60-69 years           Ontario
# 31340  2020-06-08             London  Female  20-29 years           Ontario
#
#             Outcome     Latitude     Longitude
# ...

# %%
oab.loc[oab['Gender'] == "M", 'Gender'] = "Male"
oab.loc[oab['Gender'] == "F", 'Gender'] = "Female"

# %%
oab.Age_Group.unique()
# Out:
# array(['40-49', '50-59', '20-29', '30-39', '60-69', '80-89', '10-19',
#        '70-79', '<10', '89+', '30-39 years', '60-69 years', '40-49 years',
#        '70-79 years', '50-59 years', '20-29 years', '<20 years',
#        '80+ years', 'Under 1 year', 'Unknown'], dtype=object)

# %%
oab.loc[oab['Age_Group'] == "Under 1 year", 'Age_Group'] = "<20 years"
oab.loc[oab['Age_Group'] == "10-19", 'Age_Group'] = "<20 years"
oab.loc[oab['Age_Group'] == "<10", 'Age_Group'] = "<20 years"
oab.loc[oab['Age_Group'] == "40-49", 'Age_Group'] = "40-49 years"
oab.loc[oab['Age_Group'] == "30-39", 'Age_Group'] = "30-39 years"
oab.loc[oab['Age_Group'] == "20-29", 'Age_Group'] = "20-29 years"
oab.loc[oab['Age_Group'] == "50-59", 'Age_Group'] = "50-59 years"
oab.loc[oab['Age_Group'] == "60-69", 'Age_Group'] = "60-69 years"
oab.loc[oab['Age_Group'] == "70-79", 'Age_Group'] = "70-79 years"
oab.loc[oab['Age_Group'] == "80-89", 'Age_Group'] = "80+ years"
oab.loc[oab['Age_Group'] == "89+", 'Age_Group'] = "80+ years"

# %%
oab
# Out:
#         Case_Date City/Health_Region  Gender    Age_Group          Province  \
# 0      2020-01-26  Vancouver Coastal    Male  40-49 years  British Colombia
# 1      2020-02-02  Vancouver Coastal  Female  50-59 years  British Colombia
# 2      2020-02-05  Vancouver Coastal  Female  20-29 years  British Colombia
# 3      2020-02-05  Vancouver Coastal    Male  30-39 years  British Colombia
# 4      2020-02-11           Interior  Female  30-39 years  British Colombia
# ...           ...                ...     ...          ...               ...
# 31336  2020-06-08             London    Male  60-69 years           Ontario
# 31337  2020-06-05             London    Male  20-29 years           Ontario
# 31338  2020-06-08             London    Male  20-29 years           Ontario
# 31339  2020-06-08             London  Female  60-69 years           Ontario
# 31340  2020-06-08             London  Female  20-29 years           Ontario
#
#             Outcome     Latitude     Longitude
# ...

# %%
oab["City/Health_Region"].unique()
# Out:
# array(['Vancouver Coastal', 'Interior', 'Fraser', 'Northern',
#        'Vancouver Island', 'Calgary Zone', 'Edmonton Zone',
#        'Central Zone', 'North Zone', 'South Zone', 'Unknown', 'Toronto',
#        'London', 'Newmarket', 'Whitby', 'Waterloo', 'Mississauga',
#        'Oakville', 'Ottawa', 'Sudbury', 'Hamilton', 'Cornwall', 'Barrie',
#        'Thorold', 'Port Hope', 'Stratford', 'Kenora', 'Peterborough',
#        'Owen Sound', 'Guelph', 'Brantford', 'Windsor', 'Kingston',
#        'Sault Ste. Marie', 'Timmins', 'Chatham', 'Belleville',
#        'St. Thomas', 'New Liskeard', 'North Bay', 'Point Edward',
#        'Brockville', 'Simcoe', 'Pembroke', 'Thunder Bay'], dtype=object)

# %%
oab.loc[oab['City/Health_Region'] == "Vancouver Coastal", 'Latitude'] = 54.312519
oab.loc[oab['City/Health_Region'] == "Vancouver Coastal", 'Longitude'] = -130.305405
oab.loc[oab['City/Health_Region'] == "Interior", 'Latitude'] = 52.9817
oab.loc[oab['City/Health_Region'] == "Interior", 'Longitude'] = -122.4949
oab.loc[oab['City/Health_Region'] == "Vancouver Coastal", 'Latitude'] = 54.312519
oab.loc[oab['City/Health_Region'] == "Vancouver Coastal", 'Longitude'] = -130.305405
oab.loc[oab['City/Health_Region'] == "Fraser", 'Latitude'] = 49.3795
oab.loc[oab['City/Health_Region'] == "Fraser", 'Longitude'] = -121.4417
oab.loc[oab['City/Health_Region'] == "Northern", 'Latitude'] = 58.4374
oab.loc[oab['City/Health_Region'] == "Northern", 'Longitude'] = -129.9994
oab.loc[oab['City/Health_Region'] == "Vancouver Island", 'Latitude'] = 49.7782
oab.loc[oab['City/Health_Region'] == "Vancouver Island", 'Longitude'] = -126.0496

oab.loc[oab['City/Health_Region'] == "Calgary Zone", 'Latitude'] = 51.0447
oab.loc[oab['City/Health_Region'] == "Calgary Zone", 'Longitude'] = -114.0719
oab.loc[oab['City/Health_Region'] == "Edmonton Zone", 'Latitude'] = 53.5461
oab.loc[oab['City/Health_Region'] == "Edmonton Zone", 'Longitude'] = -113.4938
oab.loc[oab['City/Health_Region'] == "Central Zone", 'Latitude'] = 52.2690
oab.loc[oab['City/Health_Region'] == "Cental Zone", 'Longitude'] = -113.8116
oab.loc[oab['City/Health_Region'] == "North Zone", 'Latitude'] =58.4649
oab.loc[oab['City/Health_Region'] == "North Zone", 'Longitude'] = -114.5361
oab.loc[oab['City/Health_Region'] == "South Zone", 'Latitude'] =50.0292
oab.loc[oab['City/Health_Region'] == "South Zone", 'Longitude'] = -110.7034

# %%
oab
# Out:
#         Case_Date City/Health_Region  Gender    Age_Group          Province  \
# 0      2020-01-26  Vancouver Coastal    Male  40-49 years  British Colombia
# 1      2020-02-02  Vancouver Coastal  Female  50-59 years  British Colombia
# 2      2020-02-05  Vancouver Coastal  Female  20-29 years  British Colombia
# 3      2020-02-05  Vancouver Coastal    Male  30-39 years  British Colombia
# 4      2020-02-11           Interior  Female  30-39 years  British Colombia
# ...           ...                ...     ...          ...               ...
# 31336  2020-06-08             London    Male  60-69 years           Ontario
# 31337  2020-06-05             London    Male  20-29 years           Ontario
# 31338  2020-06-08             London    Male  20-29 years           Ontario
# 31339  2020-06-08             London  Female  60-69 years           Ontario
# 31340  2020-06-08             London  Female  20-29 years           Ontario
#
#             Outcome     Latitude     Longitude
# ...

# %%
oab["Outcome"].unique()
# Out:
# array([nan, 'Recovered', 'Active', 'Died', 'Resolved', 'Fatal',
#        'Not Resolved'], dtype=object)

# %%
oab.loc[oab['Outcome'] == "Not Resolved", 'Outcome'] = "Active"
oab.loc[oab['Outcome'] == "Resolved", 'Outcome'] = "Recovered"
oab.loc[oab['Outcome'] == "Died", 'Outcome'] = "Fatal"
oab.loc[oab['Outcome'] == "nan", 'Outcome'] = "Unknown"

# %%
oab
# Out:
#         Case_Date City/Health_Region  Gender    Age_Group          Province  \
# 0      2020-01-26  Vancouver Coastal    Male  40-49 years  British Colombia
# 1      2020-02-02  Vancouver Coastal  Female  50-59 years  British Colombia
# 2      2020-02-05  Vancouver Coastal  Female  20-29 years  British Colombia
# 3      2020-02-05  Vancouver Coastal    Male  30-39 years  British Colombia
# 4      2020-02-11           Interior  Female  30-39 years  British Colombia
# ...           ...                ...     ...          ...               ...
# 31336  2020-06-08             London    Male  60-69 years           Ontario
# 31337  2020-06-05             London    Male  20-29 years           Ontario
# 31338  2020-06-08             London    Male  20-29 years           Ontario
# 31339  2020-06-08             London  Female  60-69 years           Ontario
# 31340  2020-06-08             London  Female  20-29 years           Ontario
#
#       Outcome     Latitude     Longitude
# ...

# %%
oab.to_csv('ONABBC_Data.csv')

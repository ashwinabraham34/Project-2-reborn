# %%
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time
import csv
from sqlalchemy import create_engine
import json
from flask import jsonify

# %%
df_data = pd.read_csv('ONABBC_Data.csv') 
df_data
# Out:
#        Unnamed: 0   Case_Date City/Health_Region  Gender    Age_Group  \
# 0               0  2020-01-26  Vancouver Coastal    Male  40-49 years
# 1               1  2020-02-02  Vancouver Coastal  Female  50-59 years
# 2               2  2020-02-05  Vancouver Coastal  Female  20-29 years
# 3               3  2020-02-05  Vancouver Coastal    Male  30-39 years
# 4               4  2020-02-11           Interior  Female  30-39 years
# ...           ...         ...                ...     ...          ...
# 41233       31336  2020-06-08             London    Male  60-69 years
# 41234       31337  2020-06-05             London    Male  20-29 years
# 41235       31338  2020-06-08             London    Male  20-29 years
# 41236       31339  2020-06-08             London  Female  60-69 years
# 41237       31340  2020-06-08             London  Female  20-29 years
#
#                Province Outcome   Latitude   Longitude
# 0      British Colombia     NaN  54.312519 -130.305405
# ...

# %%
df_data = df_data.drop(columns=['Unnamed: 0'])

# %%
engine = create_engine('postgresql://postgres:Youtube111!!!@localhost:5432/OAB_database')
df_data.to_sql('OAB', engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-e72096d2e819> in <module>
#       1 engine = create_engine('postgresql://postgres:Youtube111!!!@localhost:5432/OAB_database')
# ----> 2 df_data.to_sql('OAB', engine)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2660             chunksize=chunksize,
#    2661             dtype=dtype,
# -> 2662             method=method,
#    2663         )
#    2664
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ...

# %%
df_data.loc[df_data['Age_Group'] == "<20 years", 'Age_Group'] = "0-19 years"
df_data
# Out:
#         Case_Date City/Health_Region  Gender    Age_Group          Province  \
# 0      2020-01-26  Vancouver Coastal    Male  40-49 years  British Colombia
# 1      2020-02-02  Vancouver Coastal  Female  50-59 years  British Colombia
# 2      2020-02-05  Vancouver Coastal  Female  20-29 years  British Colombia
# 3      2020-02-05  Vancouver Coastal    Male  30-39 years  British Colombia
# 4      2020-02-11           Interior  Female  30-39 years  British Colombia
# ...           ...                ...     ...          ...               ...
# 41233  2020-06-08             London    Male  60-69 years           Ontario
# 41234  2020-06-05             London    Male  20-29 years           Ontario
# 41235  2020-06-08             London    Male  20-29 years           Ontario
# 41236  2020-06-08             London  Female  60-69 years           Ontario
# 41237  2020-06-08             London  Female  20-29 years           Ontario
#
#       Outcome   Latitude   Longitude
# ...

# %%
ON = df_data[(df_data['Province'] == "Ontario")]
AB = df_data[(df_data['Province'] == "Alberta")]

# %%
frames = [ON,AB]
ONAB = pd.concat(frames)

# %%
AB_fatal = AB[(AB['Outcome'] == "Fatal")]
ON_fatal = ON[(ON['Outcome'] == "Fatal")]
AB_fatal
# Out:
#        Case_Date City/Health_Region  Gender    Age_Group Province Outcome  \
# 2718  2020-03-17         North Zone    Male  30-39 years  Alberta   Fatal
# 2729  2020-03-14      Edmonton Zone    Male  60-69 years  Alberta   Fatal
# 2822  2020-03-19       Calgary Zone    Male  60-69 years  Alberta   Fatal
# 2864  2020-03-21      Edmonton Zone    Male    80+ years  Alberta   Fatal
# 2908  2020-03-21       Calgary Zone  Female  50-59 years  Alberta   Fatal
# ...          ...                ...     ...          ...      ...     ...
# 9121  2020-05-27       Calgary Zone    Male    80+ years  Alberta   Fatal
# 9159  2020-05-28       Calgary Zone  Female    80+ years  Alberta   Fatal
# 9303  2020-06-02       Calgary Zone    Male    80+ years  Alberta   Fatal
# 9393  2020-06-05       Calgary Zone  Female    80+ years  Alberta   Fatal
# 9599  2020-03-29       Calgary Zone  Female    80+ years  Alberta   Fatal
#
#       Latitude  Longitude
# 2718   58.4649  -114.5361
# ...

# %%
ABcount = AB.set_index(["Age_Group", "Outcome"]).count(level="Age_Group")
ABcount
AB_C = ABcount.drop(columns=['City/Health_Region', 'Gender','Province','Latitude','Longitude'])
AB_C2 = AB_C.rename(columns={"Case_Date": "Count"})
AB_C2
# Out:
#              Count
# Age_Group
# 0-19 years    1005
# 20-29 years    993
# 30-39 years   1462
# 40-49 years   1605
# 50-59 years   1042
# 60-69 years    540
# 70-79 years    247
# 80+ years      333
# Unknown          1

# %%
ONcount = ON.set_index(["Age_Group", "Outcome"]).count(level="Age_Group")
ONcount
ON_C = ONcount.drop(columns=['City/Health_Region', 'Gender','Province','Latitude','Longitude'])
ON_C2 = ON_C.rename(columns={"Case_Date": "Count"})
ON_C2
# Out:
#              Count
# Age_Group
# 0-19 years    1281
# 20-29 years   4420
# 30-39 years   4239
# 40-49 years   4474
# 50-59 years   5132
# 60-69 years   3653
# 70-79 years   2483
# 80+ years     5649
# Unknown         10

# %%
ONfcount = ON_fatal.set_index(["Age_Group", "Outcome"]).count(level="Age_Group")
ON_F_C = ONfcount.drop(columns=['City/Health_Region', 'Gender','Province','Latitude','Longitude'])
ON_F_C2 = ON_F_C.rename(columns={"Case_Date": "Count"})
ON_F_C2
# Out:
#              Count
# Age_Group
# 20-29 years      4
# 30-39 years      7
# 40-49 years     20
# 50-59 years     74
# 60-69 years    208
# 70-79 years    443
# 80+ years     1719

# %%
ABfcount = AB_fatal.set_index(["Age_Group", "Outcome"]).count(level="Age_Group")
AB_F_C = ABfcount.drop(columns=['City/Health_Region', 'Gender','Province','Latitude','Longitude'])
AB_F_C2 = AB_F_C.rename(columns={"Case_Date": "Count"})
AB_F_C2
# Out:
#              Count
# Age_Group
# 20-29 years      1
# 30-39 years      1
# 40-49 years      1
# 50-59 years      2
# 60-69 years     10
# 70-79 years     31
# 80+ years      105

# %%
engine = create_engine('postgresql://postgres:KRISS34GUN@localhost:5432/OAB_database')
AB_C2.to_sql('AB_C', engine)

# %%
engine = create_engine('postgresql://postgres:KRISS34GUN@localhost:5432/OAB_database')
ON_C2.to_sql('ON_C', engine)

# %%
engine = create_engine('postgresql://postgres:KRISS34GUN@localhost:5432/OAB_database')
AB_F_C2.to_sql('AB_F_C', engine)

# %%
engine = create_engine('postgresql://postgres:KRISS34GUN@localhost:5432/OAB_database')
ON_F_C2.to_sql('ON_F_C', engine)

# %%
AB_C2.to_csv('AB_C_Data.csv')
AB_F_C2.to_csv('AB_F_C_Data.csv')
ON_C2.to_csv('ON_C_Data.csv')
ON_F_C2.to_csv('ON_F_C_Data.csv')
